# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
# %matplotlib inline
from matplotlib import style
style.use('ggplot')

# %%
staff_list = []
with open('data/staff/staff_count_all.json') as json_file: 
    a = json.load(json_file)
    for item in a.keys():
        staff_list.append(item)
print(staff_list)
# Out:
# ['11396', '15367', '10196', '16111', '15800', '11462', '12856', '13300', '11876', '10164', '11778', '18689', '14678', '17516', '18367', '12573', '14825', '13339', '18123', '13982', '19027', '18059', '14819', '15152', '15670', '16290', '10638', '15801', '19617', '12602', '10762', '14863', '15408', '11532', '19627', '16065', '11026', '11143', '17054', '11165', '11251', '13322', '16310', '13460', '13890', '14461', '12805', '10705', '11619', '13578', '16045', '18185', '18347', '14859', '10345', '16908', '12169', '15062', '17401', '11476', '16817', '11991', '16615', '17704', '17773', '18246', '19479', '19514', '13374', '13939', '14349', '14882', '16205', '16807', '17536', '17865', '18137', '18234', '11585', '15054', '18264', '19540', '10935', '11547', '17598', '14535', '10284', '10439', '14219', '17096', '13243', '19689', '12023', '16815', '17233', '11787', '12470', '19034', '16157', '12029', '18851', '13986', '17724', '18482', '14601', '17297', '12323', '14529', '19964', '18330', '19172'
# ...

# %%
class JudgeRegion():
    """
    used to detect region for sid
    """
    def getPara(self, num):
        y = num % 100
        floor = int(num / 10000)
        x = int((num - floor * 10000) / 100)

        return x, y, floor

    def getWhere(self, num):
        if num == 0:
            return 'out'

        x, y, floor = self.getPara(num)

        if floor == 1:
            if x == 15 and (y == 5 or y == 15 or y == 17) or x == 0 and y == 19:
                return 'out'

            if 2 <= x < 4 and 1 <= y < 6:
                return 'hallA'

            if 4 <= x < 6 and 1 <= y < 6:
                return 'hallB'

            if 6 <= x < 8 and 1 <= y < 6:
                return 'hallC'

            if 8 <= x < 10 and 1 <= y < 6:
                return 'hallD'

            if 3 <= x < 10 and 7 <= y < 9:
                # return 'other'
                return 'poster'

            if 4 <= x < 6 and 10 <= y < 12:
                return 'toilet1'
                # return 'other'

            if 6 <= x < 10 and 10 <= y < 12:
                return 'room1'
                # return 'other'

            if 10 <= x < 12 and 10 <= y < 12:
                return 'room2'
                # return 'other'

            if 2 <= x < 12 and 15 <= y < 19:
                return 'exhibition'

            if 2 <= x < 12 and 19 <= y < 29:
                return 'mainHall'

            if 12 <= x < 14 and 2 <= y < 6:
                return 'register'
                # return 'other'

            if 14 <= x < 16 and 19 <= y < 21:
                return 'service'
                # return 'other'

            if 14 <= x < 16 and 21 <= y < 25:
                # return 'other'
                return 'room3'

            if 14 <= x < 16 and 25 <= y < 27:
                # return 'other'
                return 'room4'

            if 14 <= x < 16 and 27 <= y < 29:
                # return 'other'
                return 'toilet2'

            if x == 1 and 10 <= y < 12:
                # return 'Up'
                return 'elevatorUp'
                # return 'other'

            if x == 14 and 10 <= y < 12:
                # return 'Down'
                return 'elevator'
                # return 'other'

            return 'other'

        else:
            if 2 <= x < 10 and 1 <= y < 6:
                # return 'other'
                return 'diningHall'

            if 10 <= x < 12 and 1 <= y < 6:
                # return 'other'
                return 'room5'

            if 13 <= x and 0 <= y < 6:
                # return 'other'
                return 'recreationArea'

            if 4 <= x < 6 and 10 <= y < 12:
                # return 'other'
                return 'toilet3'

            if 6 <= x < 8 and 10 <= y < 12:
                # return 'other'
                return 'room6'

            if x == 1 and 10 <= y < 12:
                # return 'other'
                return 'elevatorUp'

            if x == 14 and 10 <= y < 12:
                # return 'other'
                return 'elevator'

            return 'other'

# %%
newsman_count = {}
region = JudgeRegion()
L = {}
for i in range(3):
    # tdf = pd.read_csv('data/T_df{}.csv'.format(i+1))
    day = pd.read_csv('data/day{}.csv'.format(i+1))
    
    day = day.sort_values(by=['id', 'time'], axis=0)
    # plt.figure()
    # print(tdf)
    # print(day)
    last_person_id = day.iloc[0, 0]
    flag = True
    for index, row in day.iterrows():
        if row['id'] == last_person_id:
            if not flag:
                continue
            r = region.getWhere(row['sid'])
            if r == 'register':
                flag = False
        else:
            if flag:
                if last_person_id not in L.keys():
                    L[last_person_id] = 0
                L[last_person_id] += 1
            else:
                if last_person_id in L.keys():
                    L[last_person_id] -= 20
            last_person_id = row['id']
            flag = True
    print(L)
    # last_value = ay[0]
    # print(ay)
    # dy1 = []
    # for index, row in ay.iteritems():
    #     if index == 0:
    #         continue
    #     dy = row - last_value
    #     dy1.append(dy)
    # 
    # ax = range(tdf.shape[0] - 1)
    # plt.plot(ax, dy1)
    # plt.show()
#     
# print(len(newsman_count.keys()))
# print(newsman_count)
# 
# newsman_list = []
# for key, value in newsman_count.items():
#     if key not in staff_list:
#         newsman_list.append(key)
# print(len(newsman_list))
# Out:
# {10019: 1, 10111: 1, 10181: 1, 10243: 1, 10245: 1, 10282: 1, 10401: 1, 10426: 1, 10427: 1, 10463: 1, 10502: 1, 10512: 1, 10565: 1, 10572: 1, 10594: 1, 10633: 1, 10668: 1, 10762: 1, 10781: 1, 10876: 1, 10894: 1, 10897: 1, 10957: 1, 10996: 1, 11002: 1, 11021: 1, 11026: 1, 11029: 1, 11084: 1, 11116: 1, 11150: 1, 11160: 1, 11165: 1, 11169: 1, 11197: 1, 11221: 1, 11241: 1, 11260: 1, 11278: 1, 11279: 1, 11303: 1, 11311: 1, 11317: 1, 11458: 1, 11464: 1, 11476: 1, 11537: 1, 11589: 1, 11596: 1, 11619: 1, 11662: 1, 11723: 1, 11778: 1, 11863: 1, 11869: 1, 11874: 1, 11941: 1, 11962: 1, 12019: 1, 12024: 1, 12063: 1, 12177: 1, 12260: 1, 12293: 1, 12301: 1, 12311: 1, 12312: 1, 12320: 1, 12426: 1, 12449: 1, 12555: 1, 12574: 1, 12595: 1, 12623: 1, 12664: 1, 12686: 1, 12693: 1, 12724: 1, 12726: 1, 12850: 1, 12854: 1, 12906: 1, 12939: 1, 12945: 1, 12977: 1, 12991: 1, 13003: 1, 13023: 1, 13049: 1, 13050: 1, 13147: 1, 13205: 1, 13209: 1, 13239: 1, 13263: 1, 13284: 1, 13290: 1, 13313: 1, 13344: 1, 13348: 
# ...

# %%
cnt = 0
del_list = []
new_dict = {}
for key, value in L.items():
    new_dict[str(key)] = value
with open('newsman_every.json', 'w') as json_file:
    json.dump(new_dict, json_file)

# %%
 17494, 17516, 17704, 17773, 17787, 17800, 17868, 17951, 17973, 17975, 18000, 18062, 18119, 18185, 18223, 18250, 18294, 18342, 18364, 18372, 18473, 18477, 18508, 18574, 18580, 18607, 18645, 18678, 18686, 18734, 18790, 18792, 18807, 18836, 18914, 18950, 19048, 19110, 19137, 19145, 19189, 19202, 19215, 19228, 19240, 19299, 19306, 19321, 19334, 19383, 19479, 19491, 19513, 19570, 19622, 19682, 19690, 19700, 19788, 19958]]

count = {}
for ct in range(len(regis)):
    print(ct)
    for it2 in regis[ct]:
        s = str(it2)
        if s not in count.keys():
            count[s] = 0
        count[s] += 1
print(count)
print(len(count.keys()))
# Out:
# 0
# 1
# 2
# ...

# %%
with open('newsman_2.json', 'w') as json_file:
    json.dump(count, json_file)

# %%
newsman_count = {}
region = JudgeRegion()
thres = 30


slist = []
for i in range(3):
    tdf = pd.read_csv('data/T_df{}.csv'.format(i+1))
    ids = [19145, 18608, 16975, 14338, 12574, 12311, 12024]
    sdict = {x:[] for x in ids}
    tdf_select = tdf[(tdf['id'] == 19145) | (tdf['id'] == 18608) | (tdf['id'] == 18364) | (tdf['id'] == 16975) | 
                     (tdf['id'] == 14338) | (tdf['id'] == 12574) | (tdf['id'] == 12311) | (tdf['id'] == 12024) ]
    
    for index, row in tdf.iterrows():
        for si in ids:
            if si == row['id']:
                sdict[si].append(row['in'])
                sdict[si].append(row['out'])
    print('day' + str(i+1))
    for sd in sdict.values():
        if not sd:
            sd.append(0)
            sd.append(0)
        print(sd)
    
    for index, row in tdf.iterrows():
        arrive_time = row['in']
        left_time = row['out']
        
        for si in ids:
            if abs(arrive_time - sdict[si][0]) < 300 and abs(arrive_time - sdict[si][1]) < 300:
                slist.append(row['id'])
print(slist)
# Out:
# day1
# [37090.0, 45068.0]
# [31270.0, 62776.0]
# [36860.0, 44872.0]
# [30710.0, 62001.0]
# [35020.0, 44737.0]
# [30670.0, 44653.0]
# [29630.0, 62742.0]
# day2
# [35140.0, 66196.0]
# [30820.0, 65789.0]
# [32000.0, 66589.0]
# [31270.0, 66553.0]
# [32160.0, 65956.0]
# [32700.0, 62787.0]
# [30930.0, 65964.0]
# day3
# [31900.0, 42194.0]
# [0, 0]
# [30630.0, 42888.0]
# [36770.0, 42052.0]
# [32860.0, 38260.0]
# [37150.0, 42105.0]
# [30810.0, 42750.0]
# []

# %%
# 用于找字典中的最大值，以及它的键
def keywithmaxval(d):
    """ a) create a list of the dict's keys and values; 
         b) return the key with the max value"""
    v = list(d.values())
    k=list(d.keys())
    m = max(v)
    return m, k[v.index(m)]

# %%
def read_route(file_name):
    """
    :param file_name: csv file name
    :return: route data
    """
    cols = ['id']
    cols = cols + [str(i) for i in range(782)]
    print('\n-------------------')
    print('read csv')
    print('cols:', cols)
    print('cols shape:', np.shape(cols))
    data = pd.read_csv(file_name, names=cols)
    print('data shape:', data.shape)
    print('data cols:', data.columns)

    return data

# %%
rdicts = []
stimedicts = []
region = JudgeRegion()
for n in range(1, 4):
    print('\n// --------------------------------')
    print('read route ' + str(n) )
    cols = ['id']
    cols = cols + [str(i) for i in range(782)]
    route_data = pd.read_csv('data/route' + str(n) + '.csv', names=cols).fillna(0).astype('int32')

    rdict = {}
    stay_time_dict = {}
    for index, row in route_data.iterrows():
        tmpdict = {}
        for j in range(1, route_data.shape[1]):
            t = route_data.iloc[index, j]
            if t != 0 and t != 11505 and t != 11515 and t != 11517 and t != 10019:
                temp = region.getWhere(t)
                if temp not in tmpdict.keys():
                    tmpdict[temp] = 0
                tmpdict[temp] += 1
        m, k = keywithmaxval(tmpdict)
        temp_id = str(route_data.iloc[index, 0])
        rdict[temp_id] = k
        stay_time_dict[temp_id] = m
        # k 是所在房间，m 是呆的时间
    
    rdicts.append(rdict)
    stimedicts.append(stay_time_dict)
# print(rdicts)
print('\n// --------------------------------')
# print(stimedicts)
# Out:
# // --------------------------------
# read route 1
#
# // --------------------------------
# read route 2
#
# // --------------------------------
# read route 3
#
# // --------------------------------

# %%
with open('long_time_dict.json', 'w') as json_file:
    json.dump(stimedicts, json_file)

# %%
# Out:
#       Unnamed: 0     id           T     in    out
# 3178        3178  10001  144.226190  50580  62695
# 829          829  10003   76.490566  32640  44802
# 2457        2457  10012  113.717742  30230  44331
# 706          706  10014   72.641509  28930  44330
# 1746        1746  10015   97.919162  29850  62555

# %%
tdf = pd.read_csv('T_df3.csv')
tdf = tdf.sort_values(by=['id'], axis=0)
print(tdf.head())

# for i in range(3):
tmpdict = rdicts[2]
room_list = []
for key, value in tmpdict.items():
    room_list.append(value)

tmpdict = stimedicts[2]
staytime_list = []
for key, value in tmpdict.items():
    staytime_list.append(value)

# print(room_list)
print('\n// --------------------------------')  
# print(staytime_list)
column_length = tdf.shape[1]
tdf.insert(tdf.shape[1], 'Room', room_list, True)
tdf.insert(tdf.shape[1], 'Stay Time', staytime_list, True)

tdf.to_csv('t3.csv')
# Out:
#       Unnamed: 0     id           T     in    out
# 830          830  10000   69.518519  32070  41455
# 1109        1109  10002   75.408000  32320  41746
# 967          967  10003   72.316901  31450  41719
# 1580        1580  10004   85.596330  31550  40880
# 2239        2239  10012  114.822917  31800  42823
#
# // --------------------------------

# %% [markdown]
# ### 删除用

# %%
for i in range(1,4):
    tdf = pd.read_csv('feature_set' + str(i) + '.csv')
    tdf = tdf.drop(columns=['del1', 'del2'])
    tdf.to_csv('feature_set{}.csv'.format(i))

# %%
import pandas as pd
import json

with open('data/staff/specialist.json') as json_file:
    json_d = json.load(json_file)
    room4_list = json_d.keys()

print(room4_list)

room4_10list = []
file_name = 'feature_set3_0604.csv'
tdf = pd.read_csv(file_name)
for index, row in tdf.iterrows():
    if str(row['id']) in room4_list:
        room4_10list.append(1)
    else:
        room4_10list.append(0)

tdf.insert(tdf.shape[1], 'Been Room4', room4_10list, True)
tdf.to_csv(file_name)
# Out:
# dict_keys(['10214', '10932', '11201', '11245', '11630', '12653', '13612', '13666', '14052', '15248', '15290', '15550', '15815', '16473', '16581', '17072', '17372', '17512', '18006', '19221', '19247', '19514', '19637', '10467', '12203', '13344', '13500', '16830', '17683', '17737', '19850'])
